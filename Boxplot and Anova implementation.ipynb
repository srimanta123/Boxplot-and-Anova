# %% [markdown]
# # NAME:SRIMANTA PAL
# # ROLL NUMBER: 30098120010
# # REGISTRATION NUMBER:203001898110010
# # PAPER: :DATA PREPARATION AND ANALYSIS
# # PAPER CODE:MITDS-203
# # SEMESTER: SECOND
# # DATE: 30TH JUNE,2021

# %% [markdown]
# # BOXPLOT AND ANOVA

# %% [raw]
# Importing Library

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %% [markdown]
# # 1st dataset (Image_Type2_Fuzzy_ CMU-PIE-Expression_SVM)

# %% [raw]
# Read dataset

# %%
df=pd.read_csv("Image_Type2_Fuzzy_ CMU-PIE-Expression_SVM1.csv")
df1=pd.read_csv("Image_Type2_Fuzzy_ CMU-PIE-Expression_SVM2.csv")
df2=pd.read_csv("Image_Type2_Fuzzy_ CMU-PIE-Expression_SVM3.csv")
df3=pd.read_csv("Image_Type2_Fuzzy_ CMU-PIE-Expression_SVM4.csv")

# %% [raw]
# Drop null value

# %%
data1=df.dropna()
data1.head()
# Out:
#                 Unnamed: 0               Unnamed: 1  Dia-FLD  G-Dia2DFLD  \
# 1  Expression_pie_trn_20_1  Expression_pie_tst_20_1    88.67      88.670
# 2  Expression_pie_trn_20_2  Expression_pie_tst_20_2    88.67      91.313
# 3  Expression_pie_trn_20_3  Expression_pie_tst_20_3    88.67      89.100
# 4  Expression_pie_trn_20_4  Expression_pie_tst_20_4    88.67      88.820
# 5  Expression_pie_trn_20_5  Expression_pie_tst_20_5    88.67      89.100
#
#    G2DFLD      m3      m2      m1  Type2 based Image Fused
# 1  88.670  88.670  88.670  88.670                   88.670
# 2  91.313  91.313  91.313  91.313                   92.120
# 3  91.313  89.100  89.100  89.100                   91.313
# 4  89.100  89.100  89.100  89.100                   89.890
# 5  89.100  91.313  91.313  91.313                   91.313

# %%
data2=df1.dropna()
data2.head()
# Out:
#                 Unnamed: 0               Unnamed: 1  Dia-FLD  G-Dia2DFLD  \
# 0  Expression_pie_trn_15_1  Expression_pie_tst_15_1   89.490      91.111
# 1  Expression_pie_trn_15_2  Expression_pie_tst_15_2   91.313      91.313
# 2  Expression_pie_trn_15_3  Expression_pie_tst_15_3   89.100      89.100
# 3  Expression_pie_trn_15_4  Expression_pie_tst_15_4   88.820      88.820
# 4  Expression_pie_trn_15_5  Expression_pie_tst_15_5   88.950      88.950
#
#    G2DFLD      m3      m2      m1  Type2 based Image Fused
# 0  91.111  91.313  91.313  91.313                   91.313
# 1  91.313  91.313  91.313  91.313                   91.313
# 2  89.100  89.100  89.100  89.100                   90.910
# 3  88.820  88.820  88.820  88.820                   89.100
# 4  88.950  88.950  88.950  88.950                   88.950

# %%
data3=df2.dropna()
data3.head()
# Out:
#                 Unnamed: 0               Unnamed: 1  Dia-FLD  G-Dia2DFLD  \
# 0  Expression_pie_trn_10_1  Expression_pie_tst_10_1   89.890      89.890
# 1  Expression_pie_trn_10_2  Expression_pie_tst_10_2   85.050      85.050
# 2  Expression_pie_trn_10_3  Expression_pie_tst_10_3   84.646      84.646
# 3  Expression_pie_trn_10_4  Expression_pie_tst_10_4   78.787      78.787
# 4  Expression_pie_trn_10_5  Expression_pie_tst_10_5   85.050      85.050
#
#    G2DFLD      m3      m2      m1  Type2 based Image Fused
# 0  91.111  91.111  91.111  91.313                   91.313
# 1  88.080  85.050  85.050  88.080                   88.280
# 2  85.050  85.050  85.050  85.050                   85.250
# 3  78.787  78.787  78.787  78.787                   78.787
# 4  85.050  85.050  85.050  85.050                   85.250

# %%
data4=df3.dropna()
data4.head()
# Out:
#                Unnamed: 0              Unnamed: 1  Dia-FLD  G-Dia2DFLD  \
# 0  Expression_pie_trn_5_1  Expression_pie_tst_5_1    73.49       73.49
# 1  Expression_pie_trn_5_2  Expression_pie_tst_5_2    75.56       75.56
# 2  Expression_pie_trn_5_3  Expression_pie_tst_5_3    75.15       75.15
# 3  Expression_pie_trn_5_4  Expression_pie_tst_5_4    75.15       75.15
# 4  Expression_pie_trn_5_5  Expression_pie_tst_5_5    75.12       75.12
#
#    G2DFLD     m3     m2     m1  Type2 based Image Fused
# 0   73.49  73.49  73.49  73.49                    74.98
# 1   75.56  75.56  75.56  75.56                    76.16
# 2   75.15  75.15  75.15  75.15                    75.58
# 3   75.15  75.15  75.15  75.15                    75.52
# 4   75.12  75.12  75.12  75.12                    75.58

# %% [markdown]
# # Plotting boxplot for 1st dataset

# %%
sns.set(style='white')
fig,ax=plt.subplots(figsize=(9,7))
a=sns.boxplot(data=data1,width=0.8)
plt.title('Image_Type2_Fuzzy_ CMU-PIE-Expression_SVM1',color='k',size=15)

sns.set(style='white')
fig,ax=plt.subplots(figsize=(9,7))
a=sns.boxplot(data=data2,width=0.8)
plt.title('Image_Type2_Fuzzy_ CMU-PIE-Expression_SVM2',color='r',size=15)

sns.set(style='white')
fig,ax=plt.subplots(figsize=(9,7))
a=sns.boxplot(data=data3,width=0.8)
plt.title('Image_Type2_Fuzzy_ CMU-PIE-Expression_SVM3',color='k',size=15)

sns.set(style='white')
fig,ax=plt.subplots(figsize=(9,7))
a=sns.boxplot(data=data4,width=0.8)
plt.title('Image_Type2_Fuzzy_ CMU-PIE-Expression_SVM4',color='r',size=15)
# Out:
# Text(0.5, 1.0, 'Image_Type2_Fuzzy_ CMU-PIE-Expression_SVM4')

# %% [markdown]
# # Anova for 1st dataset

# %%
data1.head(8)
# Out:
#                 Unnamed: 0               Unnamed: 1  Dia-FLD  G-Dia2DFLD  \
# 1  Expression_pie_trn_20_1  Expression_pie_tst_20_1    88.67      88.670
# 2  Expression_pie_trn_20_2  Expression_pie_tst_20_2    88.67      91.313
# 3  Expression_pie_trn_20_3  Expression_pie_tst_20_3    88.67      89.100
# 4  Expression_pie_trn_20_4  Expression_pie_tst_20_4    88.67      88.820
# 5  Expression_pie_trn_20_5  Expression_pie_tst_20_5    88.67      89.100
# 6  Expression_pie_trn_20_6  Expression_pie_tst_20_6    88.67      89.050
# 7  Expression_pie_trn_20_7  Expression_pie_tst_20_7    88.67      89.120
# 8  Expression_pie_trn_20_8  Expression_pie_tst_20_8    89.17      89.170
#
#    G2DFLD      m3      m2      m1  Type2 based Image Fused
# 1  88.670  88.670  88.670  88.670                   88.670
# 2  91.313  91.313  91.313  91.313                   92.120
# 3  91.313  89.100  89.100  89.100                   91.313
# 4  89.100  89.100  89.100  89.100                   89.890
# ...

# %%
column=[0,1]
data11=data1.drop(data1.columns[column],axis=1)
data11.head(8)
# Out:
#    Dia-FLD  G-Dia2DFLD  G2DFLD      m3      m2      m1  \
# 1    88.67      88.670  88.670  88.670  88.670  88.670
# 2    88.67      91.313  91.313  91.313  91.313  91.313
# 3    88.67      89.100  91.313  89.100  89.100  89.100
# 4    88.67      88.820  89.100  89.100  89.100  89.100
# 5    88.67      89.100  89.100  91.313  91.313  91.313
# 6    88.67      89.050  91.313  91.313  91.313  91.313
# 7    88.67      89.120  91.313  89.120  91.313  91.313
# 8    89.17      89.170  91.313  89.170  89.170  91.313
#
#    Type2 based Image Fused
# 1                   88.670
# 2                   92.120
# 3                   91.313
# 4                   89.890
# 5                   91.313
# 6                   91.313
# 7                   91.313
# 8                   91.313

# %%
data12=pd.melt(data11)
data12.head(10)
# Out:
#   variable  value
# 0  Dia-FLD  88.67
# 1  Dia-FLD  88.67
# 2  Dia-FLD  88.67
# 3  Dia-FLD  88.67
# 4  Dia-FLD  88.67
# 5  Dia-FLD  88.67
# 6  Dia-FLD  88.67
# 7  Dia-FLD  89.17
# 8  Dia-FLD  88.69
# 9  Dia-FLD  89.17

# %% [raw]
#  Anova Table

# %%
mod=ols('value ~ variable',data=data12).fit()
aov_table=sm.stats.anova_lm(mod,type=2)
print(aov_table)
# Out:
#              df      sum_sq   mean_sq         F   PR(>F)
# variable    6.0   32.067934  5.344656  3.613057  0.00237
# Residual  133.0  196.741787  1.479262       NaN      NaN

# %%
data2.head()
# Out:
#                 Unnamed: 0               Unnamed: 1  Dia-FLD  G-Dia2DFLD  \
# 0  Expression_pie_trn_15_1  Expression_pie_tst_15_1   89.490      91.111
# 1  Expression_pie_trn_15_2  Expression_pie_tst_15_2   91.313      91.313
# 2  Expression_pie_trn_15_3  Expression_pie_tst_15_3   89.100      89.100
# 3  Expression_pie_trn_15_4  Expression_pie_tst_15_4   88.820      88.820
# 4  Expression_pie_trn_15_5  Expression_pie_tst_15_5   88.950      88.950
#
#    G2DFLD      m3      m2      m1  Type2 based Image Fused
# 0  91.111  91.313  91.313  91.313                   91.313
# 1  91.313  91.313  91.313  91.313                   91.313
# 2  89.100  89.100  89.100  89.100                   90.910
# 3  88.820  88.820  88.820  88.820                   89.100
# 4  88.950  88.950  88.950  88.950                   88.950

# %%
column=[0,1]
data21=data2.drop(data2.columns[column],axis=1)
data21.head(8)
# Out:
#    Dia-FLD  G-Dia2DFLD  G2DFLD      m3      m2      m1  \
# 0   89.490      91.111  91.111  91.313  91.313  91.313
# 1   91.313      91.313  91.313  91.313  91.313  91.313
# 2   89.100      89.100  89.100  89.100  89.100  89.100
# 3   88.820      88.820  88.820  88.820  88.820  88.820
# 4   88.950      88.950  88.950  88.950  88.950  88.950
# 5   88.080      88.080  90.910  88.080  88.950  90.910
# 6   88.080      88.080  90.910  89.120  88.950  90.910
# 7   88.080      88.080  89.170  89.170  88.950  90.910
#
#    Type2 based Image Fused
# 0                   91.313
# 1                   91.313
# 2                   90.910
# 3                   89.100
# 4                   88.950
# 5                   90.910
# 6                   90.910
# 7                   90.910

# %%
data22=pd.melt(data21)
data22.head(10)
# Out:
#   variable   value
# 0  Dia-FLD  89.490
# 1  Dia-FLD  91.313
# 2  Dia-FLD  89.100
# 3  Dia-FLD  88.820
# 4  Dia-FLD  88.950
# 5  Dia-FLD  88.080
# 6  Dia-FLD  88.080
# 7  Dia-FLD  88.080
# 8  Dia-FLD  88.080
# 9  Dia-FLD  88.080

# %%
mod=ols('value ~ variable',data=data22).fit()
aov_table=sm.stats.anova_lm(mod,type=2)
print(aov_table)
# Out:
#              df     sum_sq   mean_sq         F    PR(>F)
# variable    6.0  13.971722  2.328620  3.354417  0.004132
# Residual  133.0  92.327958  0.694195       NaN       NaN

# %%
data3.head()
# Out:
#                 Unnamed: 0               Unnamed: 1  Dia-FLD  G-Dia2DFLD  \
# 0  Expression_pie_trn_10_1  Expression_pie_tst_10_1   89.890      89.890
# 1  Expression_pie_trn_10_2  Expression_pie_tst_10_2   85.050      85.050
# 2  Expression_pie_trn_10_3  Expression_pie_tst_10_3   84.646      84.646
# 3  Expression_pie_trn_10_4  Expression_pie_tst_10_4   78.787      78.787
# 4  Expression_pie_trn_10_5  Expression_pie_tst_10_5   85.050      85.050
#
#    G2DFLD      m3      m2      m1  Type2 based Image Fused
# 0  91.111  91.111  91.111  91.313                   91.313
# 1  88.080  85.050  85.050  88.080                   88.280
# 2  85.050  85.050  85.050  85.050                   85.250
# 3  78.787  78.787  78.787  78.787                   78.787
# 4  85.050  85.050  85.050  85.050                   85.250

# %%
column=[0,1]
data31=data2.drop(data2.columns[column],axis=1)
data31.head(8)
# Out:
#    Dia-FLD  G-Dia2DFLD  G2DFLD      m3      m2      m1  \
# 0   89.490      91.111  91.111  91.313  91.313  91.313
# 1   91.313      91.313  91.313  91.313  91.313  91.313
# 2   89.100      89.100  89.100  89.100  89.100  89.100
# 3   88.820      88.820  88.820  88.820  88.820  88.820
# 4   88.950      88.950  88.950  88.950  88.950  88.950
# 5   88.080      88.080  90.910  88.080  88.950  90.910
# 6   88.080      88.080  90.910  89.120  88.950  90.910
# 7   88.080      88.080  89.170  89.170  88.950  90.910
#
#    Type2 based Image Fused
# 0                   91.313
# 1                   91.313
# 2                   90.910
# 3                   89.100
# 4                   88.950
# 5                   90.910
# 6                   90.910
# 7                   90.910

# %%
data32=pd.melt(data31)
data32.head(10)
# Out:
#   variable   value
# 0  Dia-FLD  89.490
# 1  Dia-FLD  91.313
# 2  Dia-FLD  89.100
# 3  Dia-FLD  88.820
# 4  Dia-FLD  88.950
# 5  Dia-FLD  88.080
# 6  Dia-FLD  88.080
# 7  Dia-FLD  88.080
# 8  Dia-FLD  88.080
# 9  Dia-FLD  88.080

# %%
mod=ols('value ~ variable',data=data32).fit()
aov_table=sm.stats.anova_lm(mod,type=2)
print(aov_table)
# Out:
#              df     sum_sq   mean_sq         F    PR(>F)
# variable    6.0  13.971722  2.328620  3.354417  0.004132
# Residual  133.0  92.327958  0.694195       NaN       NaN

# %%
data4.head()
# Out:
#                Unnamed: 0              Unnamed: 1  Dia-FLD  G-Dia2DFLD  \
# 0  Expression_pie_trn_5_1  Expression_pie_tst_5_1    73.49       73.49
# 1  Expression_pie_trn_5_2  Expression_pie_tst_5_2    75.56       75.56
# 2  Expression_pie_trn_5_3  Expression_pie_tst_5_3    75.15       75.15
# 3  Expression_pie_trn_5_4  Expression_pie_tst_5_4    75.15       75.15
# 4  Expression_pie_trn_5_5  Expression_pie_tst_5_5    75.12       75.12
#
#    G2DFLD     m3     m2     m1  Type2 based Image Fused
# 0   73.49  73.49  73.49  73.49                    74.98
# 1   75.56  75.56  75.56  75.56                    76.16
# 2   75.15  75.15  75.15  75.15                    75.58
# 3   75.15  75.15  75.15  75.15                    75.52
# 4   75.12  75.12  75.12  75.12                    75.58

# %%
column=[0,1]
data41=data2.drop(data4.columns[column],axis=1)
data41.head(8)
# Out:
#    Dia-FLD  G-Dia2DFLD  G2DFLD      m3      m2      m1  \
# 0   89.490      91.111  91.111  91.313  91.313  91.313
# 1   91.313      91.313  91.313  91.313  91.313  91.313
# 2   89.100      89.100  89.100  89.100  89.100  89.100
# 3   88.820      88.820  88.820  88.820  88.820  88.820
# 4   88.950      88.950  88.950  88.950  88.950  88.950
# 5   88.080      88.080  90.910  88.080  88.950  90.910
# 6   88.080      88.080  90.910  89.120  88.950  90.910
# 7   88.080      88.080  89.170  89.170  88.950  90.910
#
#    Type2 based Image Fused
# 0                   91.313
# 1                   91.313
# 2                   90.910
# 3                   89.100
# 4                   88.950
# 5                   90.910
# 6                   90.910
# 7                   90.910

# %%
data42=pd.melt(data41)
data42.head(10)
# Out:
#   variable   value
# 0  Dia-FLD  89.490
# 1  Dia-FLD  91.313
# 2  Dia-FLD  89.100
# 3  Dia-FLD  88.820
# 4  Dia-FLD  88.950
# 5  Dia-FLD  88.080
# 6  Dia-FLD  88.080
# 7  Dia-FLD  88.080
# 8  Dia-FLD  88.080
# 9  Dia-FLD  88.080

# %%
mod=ols('value ~ variable',data=data42).fit()
aov_table=sm.stats.anova_lm(mod,type=2)
print(aov_table)
# Out:
#              df     sum_sq   mean_sq         F    PR(>F)
# variable    6.0  13.971722  2.328620  3.354417  0.004132
# Residual  133.0  92.327958  0.694195       NaN       NaN

# %% [markdown]
# # 2nd dataset(Image_Type2_Fuzzy_CMU-PIE-Expression_RBF)

# %%
#Read dataset
df5= pd.read_csv("Image_Type2_Fuzzy_CMU-PIE-Expression_RBF 1.csv")
df6= pd.read_csv("Image_Type2_Fuzzy_CMU-PIE-Expression_RBF 2.csv")
df7= pd.read_csv("Image_Type2_Fuzzy_CMU-PIE-Expression_RBF 3.csv")
df8= pd.read_csv("Image_Type2_Fuzzy_CMU-PIE-Expression_RBF 4.csv")

# %%
df5.head()
# Out:
#                 Unnamed: 0               Unnamed: 1  Dia-FLD  G-Dia2DFLD  \
# 0                      NaN                      NaN      NaN         NaN
# 1  Expression_pie_trn_20_1  Expression_pie_tst_20_1    88.67      88.670
# 2  Expression_pie_trn_20_2  Expression_pie_tst_20_2    88.67      91.313
# 3  Expression_pie_trn_20_3  Expression_pie_tst_20_3    88.67      89.100
# 4  Expression_pie_trn_20_4  Expression_pie_tst_20_4    88.67      88.820
#
#    G2DFLD      m3      m2      m1  Type2 based Image Fused
# 0     NaN     NaN     NaN     NaN                      NaN
# 1  88.670  88.670  88.670  88.670                   88.670
# 2  91.313  91.313  91.313  91.313                   92.120
# 3  91.313  89.100  89.100  89.100                   91.313
# 4  89.100  89.100  89.100  89.100                   89.890

# %%
data5=df5.dropna()
data6=df6.dropna()
data7=df7.dropna()
data8=df8.dropna()

# %%
data5.head()
# Out:
#                 Unnamed: 0               Unnamed: 1  Dia-FLD  G-Dia2DFLD  \
# 1  Expression_pie_trn_20_1  Expression_pie_tst_20_1    88.67      88.670
# 2  Expression_pie_trn_20_2  Expression_pie_tst_20_2    88.67      91.313
# 3  Expression_pie_trn_20_3  Expression_pie_tst_20_3    88.67      89.100
# 4  Expression_pie_trn_20_4  Expression_pie_tst_20_4    88.67      88.820
# 5  Expression_pie_trn_20_5  Expression_pie_tst_20_5    88.67      89.100
#
#    G2DFLD      m3      m2      m1  Type2 based Image Fused
# 1  88.670  88.670  88.670  88.670                   88.670
# 2  91.313  91.313  91.313  91.313                   92.120
# 3  91.313  89.100  89.100  89.100                   91.313
# 4  89.100  89.100  89.100  89.100                   89.890
# 5  89.100  91.313  91.313  91.313                   91.313

# %%
data6.head()
# Out:
#                 Unnamed: 0               Unnamed: 1  Dia-FLD  G-Dia2DFLD  \
# 0  Expression_pie_trn_15_1  Expression_pie_tst_15_1   89.490      91.111
# 1  Expression_pie_trn_15_2  Expression_pie_tst_15_2   91.313      91.313
# 2  Expression_pie_trn_15_3  Expression_pie_tst_15_3   89.100      89.100
# 3  Expression_pie_trn_15_4  Expression_pie_tst_15_4   88.820      88.820
# 4  Expression_pie_trn_15_5  Expression_pie_tst_15_5   88.950      88.950
#
#    G2DFLD      m3      m2      m1  Type2 based Image Fused
# 0  91.111  91.313  91.313  91.313                   91.313
# 1  91.313  91.313  91.313  91.313                   91.313
# 2  89.100  89.100  89.100  89.100                   90.910
# 3  88.820  88.820  88.820  88.820                   89.100
# 4  88.950  88.950  88.950  88.950                   88.950

# %%
data7.head()
# Out:
#                 Unnamed: 0               Unnamed: 1  Dia-FLD  G-Dia2DFLD  \
# 0  Expression_pie_trn_10_1  Expression_pie_tst_10_1   89.890      89.890
# 1  Expression_pie_trn_10_2  Expression_pie_tst_10_2   85.050      85.050
# 2  Expression_pie_trn_10_3  Expression_pie_tst_10_3   84.646      84.646
# 3  Expression_pie_trn_10_4  Expression_pie_tst_10_4   78.787      78.787
# 4  Expression_pie_trn_10_5  Expression_pie_tst_10_5   85.050      85.050
#
#    G2DFLD      m3      m2      m1  Type2 based Image Fused
# 0  91.111  91.111  91.111  91.313                   91.313
# 1  88.080  85.050  85.050  88.080                   88.080
# 2  85.050  85.050  85.050  85.050                   85.050
# 3  78.787  78.787  78.787  78.787                   78.787
# 4  85.050  85.050  85.050  85.050                   85.050

# %%
data8.head()
# Out:
#                Unnamed: 0              Unnamed: 1  Dia-FLD  G-Dia2DFLD  \
# 0  Expression_pie_trn_5_1  Expression_pie_tst_5_1    73.49       73.49
# 1  Expression_pie_trn_5_2  Expression_pie_tst_5_2    74.49       74.49
# 2  Expression_pie_trn_5_3  Expression_pie_tst_5_3    75.15       75.15
# 3  Expression_pie_trn_5_4  Expression_pie_tst_5_4    75.15       75.15
# 4  Expression_pie_trn_5_5  Expression_pie_tst_5_5    75.12       75.12
#
#    G2DFLD     m3     m2     m1  Type2 based Image Fused
# 0   73.49  73.49  73.49  73.49                    74.98
# 1   74.49  74.49  74.49  74.49                    74.98
# 2   75.15  75.15  75.15  75.15                    75.58
# 3   75.15  75.15  75.15  75.15                    75.52
# 4   75.12  75.12  75.12  75.12                    75.58

# %% [markdown]
# # Plotting boxplot for 2nd dataset

# %%
sns.set(style='white')
fig,ax=plt.subplots(figsize=(7,5))
a=sns.boxplot(data=data5,width=0.8)
plt.title('Image_Type2_Fuzzy_CMU-PIE-Expression_RBF 1',color='b',size=15)

sns.set(style='white')
fig,ax=plt.subplots(figsize=(7,5))
a=sns.boxplot(data=data6,width=0.8)
plt.title('Image_Type2_Fuzzy_CMU-PIE-Expression_RBF 2',color='b',size=15)

sns.set(style='white')
fig,ax=plt.subplots(figsize=(7,5))
a=sns.boxplot(data=data7,width=0.8)
plt.title('Image_Type2_Fuzzy_CMU-PIE-Expression_RBF 3',color='b',size=15)

sns.set(style='white')
fig,ax=plt.subplots(figsize=(9,7))
a=sns.boxplot(data=data8,width=0.8)
plt.title('Image_Type2_Fuzzy_CMU-PIE-Expression_RBF 4',color='b',size=15)
# Out:
# Text(0.5, 1.0, 'Image_Type2_Fuzzy_CMU-PIE-Expression_RBF 4')

# %% [markdown]
# # 3rd dataset(Image_Type2_Fuzzy_CMU-PIE-Light_RBF part)

# %%
df9= pd.read_csv("Image_Type2_Fuzzy_CMU-PIE-Light_RBF part1.csv")
df10= pd.read_csv("Image_Type2_Fuzzy_CMU-PIE-Light_RBF part 2.csv")
df11= pd.read_csv("Image_Type2_Fuzzy_CMU-PIE-Light_RBF part3.csv")
df12= pd.read_csv("Image_Type2_Fuzzy_CMU-PIE-Light_RBF part 4.csv")

# %%
data_1=df9.dropna()
data_2=df10.dropna()
data_3=df11.dropna()
data_4=df12.dropna()

# %%
data_1.head()
# Out:
#            Unnamed: 0          Unnamed: 1  Dia-FLD  G-Dia2DFLD  G2DFLD     m3  \
# 1  Light_pie_trn_20_1  Light_pie_tst_20_1    98.93       98.93   98.93  98.93
# 2  Light_pie_trn_20_2  Light_pie_tst_20_2    97.85       98.93   98.40  97.85
# 3  Light_pie_trn_20_3  Light_pie_tst_20_3    97.51       97.51   97.87  97.51
# 4  Light_pie_trn_20_4  Light_pie_tst_20_4    97.43       97.43   97.43  97.43
# 5  Light_pie_trn_20_5  Light_pie_tst_20_5    97.34       97.34   98.67  98.67
#
#       m2     m1  Type2 based Image Fused
# 1  98.93  98.93                    99.47
# 2  98.40  97.87                    98.40
# 3  97.87  97.60                    98.40
# 4  97.43  97.43                    97.60
# 5  98.67  98.67                    98.93

# %%
data_2.head()
# Out:
#            Unnamed: 0          Unnamed: 1  Dia-FLD  G-Dia2DFLD  G2DFLD     m3  \
# 0  Light_pie_trn_15_1  Light_pie_tst_15_1    91.98       91.98   95.16  95.16
# 1  Light_pie_trn_15_2  Light_pie_tst_15_2    91.90       91.90   91.90  91.90
# 2  Light_pie_trn_15_3  Light_pie_tst_15_3    91.90       91.90   91.90  91.90
# 3  Light_pie_trn_15_4  Light_pie_tst_15_4    91.19       91.85   91.85  91.85
# 4  Light_pie_trn_15_5  Light_pie_tst_15_5    91.19       92.31   92.31  92.31
#
#       m2     m1  Type2 based Image Fused
# 0  95.16  95.16                    95.16
# 1  91.90  91.90                    91.90
# 2  91.90  91.90                    92.97
# 3  91.85  91.90                    92.97
# 4  92.97  92.97                    92.97

# %%
data_3.head()
# Out:
#            Unnamed: 0          Unnamed: 1  Dia-FLD  G-Dia2DFLD  G2DFLD  \
# 0  Light_pie_trn_10_1  Light_pie_tst_10_1   95.160      95.160  95.160
# 1  Light_pie_trn_10_2  Light_pie_tst_10_2   91.868      91.868  91.868
# 2  Light_pie_trn_10_3  Light_pie_tst_10_3   88.080      88.080  94.065
# 3  Light_pie_trn_10_4  Light_pie_tst_10_4   93.410      93.410  93.410
# 4  Light_pie_trn_10_5  Light_pie_tst_10_5   88.080      88.080  88.080
#
#        m3     m2      m1  Type2 based Image Fused
# 0  95.160  95.16  95.160                    95.56
# 1  91.868  92.57  92.970                    92.97
# 2  93.280  93.28  94.065                    94.16
# 3  93.410  93.41  93.410                    93.85
# 4  88.080  88.08  88.080                    88.08

# %%
data_4.head()
# Out:
#           Unnamed: 0         Unnamed: 1  Dia-FLD  G-Dia2DFLD  G2DFLD     m3  \
# 0  Light_pie_trn_5_1  Light_pie_tst_5_1    80.44       80.44   80.44  80.44
# 1  Light_pie_trn_5_2  Light_pie_tst_5_2    86.66       86.66   86.66  86.66
# 2  Light_pie_trn_5_3  Light_pie_tst_5_3    80.36       80.36   80.36  80.36
# 3  Light_pie_trn_5_4  Light_pie_tst_5_4    80.31       80.31   80.31  80.31
# 4  Light_pie_trn_5_5  Light_pie_tst_5_5    80.29       80.29   80.29  80.29
#
#       m2     m1  Type2 based Image Fused
# 0  80.44  80.44                    81.44
# 1  86.66  86.66                    87.66
# 2  80.36  80.36                    81.08
# 3  80.31  80.31                    81.31
# 4  80.29  81.29                    82.08

# %% [markdown]
# # Plotting boxpolt for 3rd dataset

# %%
sns.set(style='white')
fig,ax=plt.subplots(figsize=(7,5))
a=sns.boxplot(data=data_1,width=0.8)
plt.title('Image_Type2_Fuzzy_CMU-PIE-Light_RBF part1',color='k',size=15)

sns.set(style='white')
fig,ax=plt.subplots(figsize=(7,5))
a=sns.boxplot(data=data_2,width=0.8)
plt.title('Image_Type2_Fuzzy_CMU-PIE-Light_RBF part2',color='k',size=15)

sns.set(style='white')
fig,ax=plt.subplots(figsize=(7,5))
a=sns.boxplot(data=data_3,width=0.8)
plt.title('Image_Type2_Fuzzy_CMU-PIE-Light_RBF part3',color='k',size=15)

sns.set(style='white')
fig,ax=plt.subplots(figsize=(9,7))
a=sns.boxplot(data=data_4,width=0.8)
plt.title('Image_Type2_Fuzzy_CMU-PIE-Light_RBF part_4',color='k',size=15)
# Out:
# Text(0.5, 1.0, 'Image_Type2_Fuzzy_CMU-PIE-Light_RBF part_4')

# %% [markdown]
# # Anova for 3rd dataset

# %%
column=[0,1]
data_5=data_1.drop(data_1.columns[column],axis=1)
data_5
# Out:
#     Dia-FLD  G-Dia2DFLD  G2DFLD     m3      m2      m1  \
# 1     98.93       98.93  98.930  98.93  98.930  98.930
# 2     97.85       98.93  98.400  97.85  98.400  97.870
# 3     97.51       97.51  97.870  97.51  97.870  97.600
# 4     97.43       97.43  97.430  97.43  97.430  97.430
# 5     97.34       97.34  98.670  98.67  98.670  98.670
# 6     97.31       97.31  97.310  97.31  97.310  97.310
# 7     97.60       97.60  97.600  97.37  97.070  97.070
# 8     97.34       97.34  98.130  97.34  98.130  98.630
# 9     97.34       97.57  97.330  97.57  97.330  98.630
# 10    97.34       97.60  98.400  97.60  98.400  97.600
# 11    97.34       97.51  97.870  97.51  97.510  97.870
# 12    97.48       97.48  95.470  97.48  95.470  96.830
# 13    97.43       97.43  97.330  98.13  98.130  98.130
# 14    97.57       97.57  98.130  98.13  98.130  98.130
# 15    96.33       96.33  96.330  97.48  96.330  96.330
# 16    96.33       97.48  98.933  97.48  98.933  99.470
# ...

# %%
data_6=pd.melt(data_5)

# %%
data_6.head(12)
# Out:
#    variable  value
# 0   Dia-FLD  98.93
# 1   Dia-FLD  97.85
# 2   Dia-FLD  97.51
# 3   Dia-FLD  97.43
# 4   Dia-FLD  97.34
# 5   Dia-FLD  97.31
# 6   Dia-FLD  97.60
# 7   Dia-FLD  97.34
# 8   Dia-FLD  97.34
# 9   Dia-FLD  97.34
# 10  Dia-FLD  97.34
# 11  Dia-FLD  97.48

# %%
mod=ols('value ~ variable',data=data_6).fit()
aov_table=sm.stats.anova_lm(mod,type=2)
print(aov_table)
# Out:
#              df     sum_sq   mean_sq         F    PR(>F)
# variable    6.0  10.557231  1.759538  3.201614  0.005732
# Residual  133.0  73.093948  0.549579       NaN       NaN

# %%
column=[0,1]
data_8=data_2.drop(data_2.columns[column],axis=1)
data_8.head(5)
# Out:
#    Dia-FLD  G-Dia2DFLD  G2DFLD     m3     m2     m1  Type2 based Image Fused
# 0    91.98       91.98   95.16  95.16  95.16  95.16                    95.16
# 1    91.90       91.90   91.90  91.90  91.90  91.90                    91.90
# 2    91.90       91.90   91.90  91.90  91.90  91.90                    92.97
# 3    91.19       91.85   91.85  91.85  91.85  91.90                    92.97
# 4    91.19       92.31   92.31  92.31  92.97  92.97                    92.97

# %%
data_9=pd.melt(data_8)

# %%
data_9.head()
# Out:
#   variable  value
# 0  Dia-FLD  91.98
# 1  Dia-FLD  91.90
# 2  Dia-FLD  91.90
# 3  Dia-FLD  91.19
# 4  Dia-FLD  91.19

# %%
mod=ols('value ~ variable',data=data_9).fit()
aov_table=sm.stats.anova_lm(mod,type=2)
print(aov_table)
# Out:
#              df     sum_sq   mean_sq         F    PR(>F)
# variable    6.0  18.400199  3.066700  4.593745  0.000286
# Residual  133.0  88.788366  0.667582       NaN       NaN

# %%
column=[0,1]
data_10=data_3.drop(data_3.columns[column],axis=1)
data_10.head(5)
# Out:
#    Dia-FLD  G-Dia2DFLD  G2DFLD      m3     m2      m1  Type2 based Image Fused
# 0   95.160      95.160  95.160  95.160  95.16  95.160                    95.56
# 1   91.868      91.868  91.868  91.868  92.57  92.970                    92.97
# 2   88.080      88.080  94.065  93.280  93.28  94.065                    94.16
# 3   93.410      93.410  93.410  93.410  93.41  93.410                    93.85
# 4   88.080      88.080  88.080  88.080  88.08  88.080                    88.08

# %%
data_11=pd.melt(data_10)

# %%
data_11.head()
# Out:
#   variable   value
# 0  Dia-FLD  95.160
# 1  Dia-FLD  91.868
# 2  Dia-FLD  88.080
# 3  Dia-FLD  93.410
# 4  Dia-FLD  88.080

# %%
mod=ols('value ~ variable',data=data_11).fit()
aov_table=sm.stats.anova_lm(mod,type=2)
print(aov_table)
# Out:
#              df       sum_sq    mean_sq         F    PR(>F)
# variable    6.0     8.511034   1.418506  0.059963  0.999118
# Residual  133.0  3146.302813  23.656412       NaN       NaN

# %%
column=[0,1]
data_14=data_3.drop(data_3.columns[column],axis=1)
data_14.head(5)
# Out:
#    Dia-FLD  G-Dia2DFLD  G2DFLD      m3     m2      m1  Type2 based Image Fused
# 0   95.160      95.160  95.160  95.160  95.16  95.160                    95.56
# 1   91.868      91.868  91.868  91.868  92.57  92.970                    92.97
# 2   88.080      88.080  94.065  93.280  93.28  94.065                    94.16
# 3   93.410      93.410  93.410  93.410  93.41  93.410                    93.85
# 4   88.080      88.080  88.080  88.080  88.08  88.080                    88.08

# %%
data_15=pd.melt(data_14)

# %%
data_15.head(5)
# Out:
#   variable   value
# 0  Dia-FLD  95.160
# 1  Dia-FLD  91.868
# 2  Dia-FLD  88.080
# 3  Dia-FLD  93.410
# 4  Dia-FLD  88.080

# %%
mod=ols('value ~ variable',data=data_15).fit()
aov_table=sm.stats.anova_lm(mod,type=2)
print(aov_table)
# Out:
#              df       sum_sq    mean_sq         F    PR(>F)
# variable    6.0     8.511034   1.418506  0.059963  0.999118
# Residual  133.0  3146.302813  23.656412       NaN       NaN

# %% [markdown]
# # 4th dataset(Image_Type2_Fuzzy_Umist_SVM part)

# %%
#read dataset and drop null values

df_df_1= pd.read_csv("Image_Type2_Fuzzy_Umist_SVM part_1.csv")
df_df_2= pd.read_csv("Image_Type2_Fuzzy_Umist_SVM part_2.csv")
df_df_3= pd.read_csv("Image_Type2_Fuzzy_Umist_SVM part_3.csv")
df_df_4= pd.read_csv("Image_Type2_Fuzzy_Umist_SVM part_4.csv")
df_df11=df_df_1.dropna()
df_df12=df_df_2.dropna()
df_df13=df_df_3.dropna()
df_df14=df_df_4.dropna()

# %%
df_df11.head()
# Out:
#        Unnamed: 0      Unnamed: 1  Dia-FLD  G-Dia2DFLD  G2DFLD     m3     m2  \
# 1  Umist_trn_10_1  Umist_tst_10_1    97.33       97.33   97.33  97.33  97.33
# 2  Umist_trn_10_2  Umist_tst_10_2    97.33       97.33   97.33  98.40  98.40
# 3  Umist_trn_10_3  Umist_tst_10_3    96.80       97.33   97.87  97.87  97.87
# 4  Umist_trn_10_4  Umist_tst_10_4    95.47       95.47   96.83  96.83  96.83
# 5  Umist_trn_10_5  Umist_tst_10_5    98.93       98.93   98.93  98.67  98.67
#
#       m1  Type2 based Image Fused
# 1  98.40                    98.93
# 2  99.47                    99.47
# 3  98.40                    98.93
# 4  96.83                    97.33
# 5  99.47                    99.47

# %%
df_df12.head()
# Out:
#       Unnamed: 0     Unnamed: 1  Dia-FLD  G-Dia2DFLD  G2DFLD     m3     m2  \
# 0  Umist_trn_8_1  Umist_tst_8_1    94.84       94.84   95.18  94.84  95.18
# 1  Umist_trn_8_2  Umist_tst_8_2    95.18       95.18   95.42  94.84  95.42
# 2  Umist_trn_8_3  Umist_tst_8_3    95.18       95.18   95.36  94.84  95.66
# 3  Umist_trn_8_4  Umist_tst_8_4    97.35       97.35   97.35  94.84  97.35
# 4  Umist_trn_8_5  Umist_tst_8_5    95.42       95.42   95.42  94.84  95.42
#
#        m1  Type2 based Image Fused
# 0  96.867                   96.867
# 1  95.420                   96.867
# 2  96.867                   96.867
# 3  97.350                   97.350
# 4  96.040                   96.140

# %%
df_df13.head()
# Out:
#       Unnamed: 0     Unnamed: 1  Dia-FLD  G-Dia2DFLD  G2DFLD     m3     m2  \
# 0  Umist_trn_6_1  Umist_tst_6_1    91.65       91.65   91.65  88.79  91.65
# 1  Umist_trn_6_2  Umist_tst_6_2    89.67       91.65   89.67  88.79  89.67
# 2  Umist_trn_6_3  Umist_tst_6_3    91.21       91.65   93.85  88.79  92.97
# 3  Umist_trn_6_4  Umist_tst_6_4    91.21       91.65   93.19  88.79  93.19
# 4  Umist_trn_6_5  Umist_tst_6_5    91.21       91.65   91.21  88.79  91.21
#
#       m1  Type2 based Image Fused
# 0  91.65                    92.09
# 1  89.67                    89.67
# 2  93.85                    93.85
# 3  93.85                    93.85
# 4  91.21                    91.51

# %%
df_df14.head()
# Out:
#       Unnamed: 0     Unnamed: 1  Dia-FLD  G-Dia2DFLD  G2DFLD      m3      m2  \
# 0  Umist_trn_4_1  Umist_tst_4_1    88.08      88.080  88.080  88.080  88.080
# 1  Umist_trn_4_2  Umist_tst_4_2    85.05      85.050  85.050  85.050  85.050
# 2  Umist_trn_4_3  Umist_tst_4_3    84.84      84.840  84.840  84.840  84.840
# 3  Umist_trn_4_4  Umist_tst_4_4    78.99      78.787  78.787  78.787  78.787
# 4  Umist_trn_4_5  Umist_tst_4_5    85.05      85.050  86.670  78.787  85.050
#
#        m1  Type2 based Image Fused
# 0  89.490                   89.490
# 1  85.050                   85.050
# 2  85.850                   86.260
# 3  78.787                   78.787
# 4  86.670                   86.670

# %% [markdown]
# # Plotting boxplot for 4th dataset

# %%
sns.set(style='white')
fig,ax=plt.subplots(figsize=(7,5))
a=sns.boxplot(data=df_df11,width=0.8)
plt.title('Image_Type2_Fuzzy_Umist_SVM part_1',color='k',size=15)

sns.set(style='white')
fig,ax=plt.subplots(figsize=(7,5))
a=sns.boxplot(data=df_df12,width=0.8)
plt.title('Image_Type2_Fuzzy_Umist_SVM part_2',color='k',size=15)

sns.set(style='white')
fig,ax=plt.subplots(figsize=(7,5))
a=sns.boxplot(data=df_df13,width=0.8)
plt.title('Image_Type2_Fuzzy_Umist_SVM part_3',color='k',size=15)

sns.set(style='white')
fig,ax=plt.subplots(figsize=(9,7))
a=sns.boxplot(data=df_df14,width=0.8)
plt.title('Image_Type2_Fuzzy_Umist_SVM part_4',color='k',size=15)
# Out:
# Text(0.5, 1.0, 'Image_Type2_Fuzzy_Umist_SVM part_4')

# %% [markdown]
# # Anova for 4th dataset

# %%
column=[0,1]
data_df1=df_df11.drop(df_df11.columns[column],axis=1)
data_df1.head(5)
# Out:
#    Dia-FLD  G-Dia2DFLD  G2DFLD     m3     m2     m1  Type2 based Image Fused
# 1    97.33       97.33   97.33  97.33  97.33  98.40                    98.93
# 2    97.33       97.33   97.33  98.40  98.40  99.47                    99.47
# 3    96.80       97.33   97.87  97.87  97.87  98.40                    98.93
# 4    95.47       95.47   96.83  96.83  96.83  96.83                    97.33
# 5    98.93       98.93   98.93  98.67  98.67  99.47                    99.47

# %%
data_30=pd.melt(data_df1)

# %%
data_30.head(10)
# Out:
#   variable  value
# 0  Dia-FLD  97.33
# 1  Dia-FLD  97.33
# 2  Dia-FLD  96.80
# 3  Dia-FLD  95.47
# 4  Dia-FLD  98.93
# 5  Dia-FLD  96.27
# 6  Dia-FLD  97.60
# 7  Dia-FLD  96.80
# 8  Dia-FLD  95.73
# 9  Dia-FLD  95.20

# %%
mod=ols('value ~ variable',data=data_30).fit()
aov_table=sm.stats.anova_lm(mod,type=2)
print(aov_table)
# Out:
#              df      sum_sq   mean_sq         F        PR(>F)
# variable    6.0   52.479315  8.746552  7.507624  6.080199e-07
# Residual  133.0  154.948028  1.165023       NaN           NaN

# %%
column=[0,1]
data_df2=df_df12.drop(df_df12.columns[column],axis=1)
data_df2.head(5)
# Out:
#    Dia-FLD  G-Dia2DFLD  G2DFLD     m3     m2      m1  Type2 based Image Fused
# 0    94.84       94.84   95.18  94.84  95.18  96.867                   96.867
# 1    95.18       95.18   95.42  94.84  95.42  95.420                   96.867
# 2    95.18       95.18   95.36  94.84  95.66  96.867                   96.867
# 3    97.35       97.35   97.35  94.84  97.35  97.350                   97.350
# 4    95.42       95.42   95.42  94.84  95.42  96.040                   96.140

# %%
data_31=pd.melt(data_df2)

# %%
data_31.head()
# Out:
#   variable  value
# 0  Dia-FLD  94.84
# 1  Dia-FLD  95.18
# 2  Dia-FLD  95.18
# 3  Dia-FLD  97.35
# 4  Dia-FLD  95.42

# %%
mod=ols('value ~ variable',data=data_31).fit()
aov_table=sm.stats.anova_lm(mod,type=2)
print(aov_table)
# Out:
#              df      sum_sq    mean_sq          F        PR(>F)
# variable    6.0   73.685044  12.280841  14.055442  2.395019e-12
# Residual  133.0  116.207785   0.873743        NaN           NaN

# %%
column=[0,1]
data_df3=df_df13.drop(df_df13.columns[column],axis=1)
data_df3.head(5)
# Out:
#    Dia-FLD  G-Dia2DFLD  G2DFLD     m3     m2     m1  Type2 based Image Fused
# 0    91.65       91.65   91.65  88.79  91.65  91.65                    92.09
# 1    89.67       91.65   89.67  88.79  89.67  89.67                    89.67
# 2    91.21       91.65   93.85  88.79  92.97  93.85                    93.85
# 3    91.21       91.65   93.19  88.79  93.19  93.85                    93.85
# 4    91.21       91.65   91.21  88.79  91.21  91.21                    91.51

# %%
data_32=pd.melt(data_df3)

# %%
data_32.head()
# Out:
#   variable  value
# 0  Dia-FLD  91.65
# 1  Dia-FLD  89.67
# 2  Dia-FLD  91.21
# 3  Dia-FLD  91.21
# 4  Dia-FLD  91.21

# %%
mod=ols('value ~ variable',data=data_32).fit()
aov_table=sm.stats.anova_lm(mod,type=2)
print(aov_table)
# Out:
#              df      sum_sq    mean_sq         F    PR(>F)
# variable    6.0   93.244279  15.540713  5.007787  0.000117
# Residual  133.0  412.740133   3.103309       NaN       NaN

# %%
column=[0,1]
data_df4=df_df14.drop(df_df14.columns[column],axis=1)
data_df4.head(5)
# Out:
#    Dia-FLD  G-Dia2DFLD  G2DFLD      m3      m2      m1  \
# 0    88.08      88.080  88.080  88.080  88.080  89.490
# 1    85.05      85.050  85.050  85.050  85.050  85.050
# 2    84.84      84.840  84.840  84.840  84.840  85.850
# 3    78.99      78.787  78.787  78.787  78.787  78.787
# 4    85.05      85.050  86.670  78.787  85.050  86.670
#
#    Type2 based Image Fused
# 0                   89.490
# 1                   85.050
# 2                   86.260
# 3                   78.787
# 4                   86.670

# %%
data_33=pd.melt(data_df4)

# %%
data_33.head()
# Out:
#   variable  value
# 0  Dia-FLD  88.08
# 1  Dia-FLD  85.05
# 2  Dia-FLD  84.84
# 3  Dia-FLD  78.99
# 4  Dia-FLD  85.05

# %%
mod=ols('value ~ variable',data=data_33).fit()
aov_table=sm.stats.anova_lm(mod,type=2)
print(aov_table)
# Out:
#              df       sum_sq    mean_sq        F    PR(>F)
# variable    6.0   203.939244  33.989874  4.39158  0.000442
# Residual  133.0  1029.391143   7.739783      NaN       NaN

# %% [markdown]
# # 5th dataset(Image_Type2_Fuzzy_Umist_RBF)

# %%
# Read dataset

df_frame1= pd.read_csv("Image_Type2_Fuzzy_Umist_RBF part1.csv")
df_frame2= pd.read_csv("Image_Type2_Fuzzy_Umist_RBF part2.csv")
df_frame3= pd.read_csv("Image_Type2_Fuzzy_Umist_RBF part3.csv")
df_frame4= pd.read_csv("Image_Type2_Fuzzy_Umist_RBF part4.csv")

# %%
df_frame1.dropna().head()
# Out:
#        Unnamed: 0      Unnamed: 1  Dia-FLD  G-Dia2DFLD  G2DFLD     m3     m2  \
# 1  Umist_trn_10_1  Umist_tst_10_1    97.33       97.33   97.33  97.33  97.33
# 2  Umist_trn_10_2  Umist_tst_10_2    97.33       97.33   97.33  98.40  98.40
# 3  Umist_trn_10_3  Umist_tst_10_3    96.80       97.33   97.87  97.87  97.87
# 4  Umist_trn_10_4  Umist_tst_10_4    95.47       95.47   96.83  96.83  96.83
# 5  Umist_trn_10_5  Umist_tst_10_5    98.93       98.93   98.93  98.67  98.67
#
#       m1  Type2 based Image Fused
# 1  98.40                    98.93
# 2  99.47                    99.47
# 3  98.40                    98.93
# 4  96.83                    97.33
# 5  99.47                    99.47

# %%
df_frame2.dropna().head()
# Out:
#       Unnamed: 0     Unnamed: 1  Dia-FLD  G-Dia2DFLD  G2DFLD     m3     m2  \
# 0  Umist_trn_8_1  Umist_tst_8_1    94.84       94.84   95.18  94.84  95.18
# 1  Umist_trn_8_2  Umist_tst_8_2    95.18       95.18   95.42  94.84  95.42
# 2  Umist_trn_8_3  Umist_tst_8_3    95.18       95.18   95.36  94.84  95.66
# 3  Umist_trn_8_4  Umist_tst_8_4    97.35       97.35   97.35  94.84  97.35
# 4  Umist_trn_8_5  Umist_tst_8_5    95.42       95.42   95.42  94.84  95.42
#
#        m1  Type2 based Image Fused
# 0  96.867                   96.867
# 1  95.420                   96.867
# 2  96.867                   96.867
# 3  97.350                   97.350
# 4  96.040                   96.140

# %%
df_frame3.dropna().head()
# Out:
#       Unnamed: 0     Unnamed: 1  Dia-FLD  G-Dia2DFLD  G2DFLD     m3     m2  \
# 0  Umist_trn_6_1  Umist_tst_6_1    91.65       91.65   91.65  88.79  91.65
# 1  Umist_trn_6_2  Umist_tst_6_2    89.67       91.65   89.67  88.79  89.67
# 2  Umist_trn_6_3  Umist_tst_6_3    91.21       91.65   93.85  88.79  92.97
# 3  Umist_trn_6_4  Umist_tst_6_4    91.21       91.65   93.19  88.79  93.19
# 4  Umist_trn_6_5  Umist_tst_6_5    91.21       91.65   91.21  88.79  91.21
#
#       m1  Type2 based Image Fused
# 0  91.65                    92.09
# 1  89.67                    89.67
# 2  93.85                    93.85
# 3  93.85                    93.85
# 4  91.21                    91.51

# %%
df_frame4.dropna().head()
# Out:
#       Unnamed: 0     Unnamed: 1  Dia-FLD  G-Dia2DFLD  G2DFLD      m3      m2  \
# 0  Umist_trn_4_1  Umist_tst_4_1    88.08      88.080  88.080  88.080  88.080
# 1  Umist_trn_4_2  Umist_tst_4_2    85.05      85.050  85.050  85.050  85.050
# 2  Umist_trn_4_3  Umist_tst_4_3    83.84      83.840  83.840  83.840  83.840
# 3  Umist_trn_4_4  Umist_tst_4_4    78.99      78.787  78.787  78.787  78.787
# 4  Umist_trn_4_5  Umist_tst_4_5    85.05      85.050  86.670  78.787  85.050
#
#        m1  Type2 based Image Fused
# 0  89.490                   89.490
# 1  85.050                   85.050
# 2  85.450                   85.450
# 3  78.787                   78.787
# 4  86.670                   86.670

# %% [markdown]
# # Plotting boxplot for 5th dataset

# %%
sns.set(style='white')
fig,ax=plt.subplots(figsize=(8,6))
a=sns.boxplot(data=df_frame1,width=0.7,showmeans=True)
plt.title("Image_Type2_Fuzzy_Umist_RBF part1.csv")

sns.set(style='white')

fig,ax=plt.subplots(figsize=(8,6))
a=sns.boxplot(data=df_frame2,width=0.7,showmeans=True)
plt.title("Image_Type2_Fuzzy_Umist_RBF part2.csv")

sns.set(style='white')
fig,ax=plt.subplots(figsize=(8,6))
a=sns.boxplot(data=df_frame3,width=0.7,showmeans=True)
plt.title("Image_Type2_Fuzzy_Umist_RBF part3.csv")

sns.set(style='white')
fig,ax=plt.subplots(figsize=(8,6))
a=sns.boxplot(data=df_frame4,width=0.7,showmeans=True)
plt.title("Image_Type2_Fuzzy_Umist_RBF part4.csv")

plt.show()

# %% [markdown]
# # Anova for 5th dataset

# %%
df_fr=df_frame1.drop(['Unnamed: 0','Unnamed: 1'],axis=1)
df_fr.reset_index(drop=True,inplace=True)
df_fr.head()
# Out:
#    Dia-FLD  G-Dia2DFLD  G2DFLD     m3     m2     m1  Type2 based Image Fused
# 0      NaN         NaN     NaN    NaN    NaN    NaN                      NaN
# 1    97.33       97.33   97.33  97.33  97.33  98.40                    98.93
# 2    97.33       97.33   97.33  98.40  98.40  99.47                    99.47
# 3    96.80       97.33   97.87  97.87  97.87  98.40                    98.93
# 4    95.47       95.47   96.83  96.83  96.83  96.83                    97.33

# %%
df_fr1=df_fr.dropna()
df_fr1.head()
# Out:
#    Dia-FLD  G-Dia2DFLD  G2DFLD     m3     m2     m1  Type2 based Image Fused
# 1    97.33       97.33   97.33  97.33  97.33  98.40                    98.93
# 2    97.33       97.33   97.33  98.40  98.40  99.47                    99.47
# 3    96.80       97.33   97.87  97.87  97.87  98.40                    98.93
# 4    95.47       95.47   96.83  96.83  96.83  96.83                    97.33
# 5    98.93       98.93   98.93  98.67  98.67  99.47                    99.47

# %%
df_fr2=pd.melt(df_fr1)
df_fr2.head()
# Out:
#   variable  value
# 0  Dia-FLD  97.33
# 1  Dia-FLD  97.33
# 2  Dia-FLD  96.80
# 3  Dia-FLD  95.47
# 4  Dia-FLD  98.93

# %%
mod=ols('value~variable',data=df_fr2).fit()
aov_table=sm.stats.anova_lm(mod,type=2)
aov_table
# Out:
#              df      sum_sq   mean_sq         F    PR(>F)
# variable    6.0   51.438864  8.573144  6.951555  0.000002
# Residual  133.0  164.024903  1.233270       NaN       NaN

# %%
df_fr2=df_frame2.drop(['Unnamed: 0','Unnamed: 1'],axis=1) 
df_fr2.reset_index(drop=True,inplace=True)
df_fr2.head()
# Out:
#    Dia-FLD  G-Dia2DFLD  G2DFLD     m3     m2      m1  Type2 based Image Fused
# 0    94.84       94.84   95.18  94.84  95.18  96.867                   96.867
# 1    95.18       95.18   95.42  94.84  95.42  95.420                   96.867
# 2    95.18       95.18   95.36  94.84  95.66  96.867                   96.867
# 3    97.35       97.35   97.35  94.84  97.35  97.350                   97.350
# 4    95.42       95.42   95.42  94.84  95.42  96.040                   96.140

# %%
df_fr3=pd.melt(df_fr2)
df_fr3.head()
# Out:
#   variable  value
# 0  Dia-FLD  94.84
# 1  Dia-FLD  95.18
# 2  Dia-FLD  95.18
# 3  Dia-FLD  97.35
# 4  Dia-FLD  95.42

# %%
mod=ols('value~variable',data=df_fr3).fit()
aov_table=sm.stats.anova_lm(mod,type=2)
aov_table
# Out:
#              df      sum_sq    mean_sq          F        PR(>F)
# variable    6.0   71.652511  11.942085  11.543812  2.241450e-10
# Residual  133.0  137.588638   1.034501        NaN           NaN

# %%
df_fr4=df_frame3.drop(['Unnamed: 0','Unnamed: 1'],axis=1) 
df_fr4.reset_index(drop=True,inplace=True)
df_fr4.head()
# Out:
#    Dia-FLD  G-Dia2DFLD  G2DFLD     m3     m2     m1  Type2 based Image Fused
# 0    91.65       91.65   91.65  88.79  91.65  91.65                    92.09
# 1    89.67       91.65   89.67  88.79  89.67  89.67                    89.67
# 2    91.21       91.65   93.85  88.79  92.97  93.85                    93.85
# 3    91.21       91.65   93.19  88.79  93.19  93.85                    93.85
# 4    91.21       91.65   91.21  88.79  91.21  91.21                    91.51

# %%
df_fr5=pd.melt(df_fr4)
df_fr5.head()
# Out:
#   variable  value
# 0  Dia-FLD  91.65
# 1  Dia-FLD  89.67
# 2  Dia-FLD  91.21
# 3  Dia-FLD  91.21
# 4  Dia-FLD  91.21

# %%
mod=ols('value~variable',data=df_fr5).fit()
aov_table=sm.stats.anova_lm(mod,type=2)
aov_table
# Out:
#              df      sum_sq    mean_sq         F    PR(>F)
# variable    6.0   87.442006  14.573668  4.403631  0.000431
# Residual  133.0  440.159035   3.309466       NaN       NaN

# %%
df_fr6=df_frame4.drop(['Unnamed: 0','Unnamed: 1'],axis=1) 
df_fr6.reset_index(drop=True,inplace=True)
df_fr6.head()
# Out:
#    Dia-FLD  G-Dia2DFLD  G2DFLD      m3      m2      m1  \
# 0    88.08      88.080  88.080  88.080  88.080  89.490
# 1    85.05      85.050  85.050  85.050  85.050  85.050
# 2    83.84      83.840  83.840  83.840  83.840  85.450
# 3    78.99      78.787  78.787  78.787  78.787  78.787
# 4    85.05      85.050  86.670  78.787  85.050  86.670
#
#    Type2 based Image Fused
# 0                   89.490
# 1                   85.050
# 2                   85.450
# 3                   78.787
# 4                   86.670

# %%
df_fr7=pd.melt(df_fr6)
df_fr7.head()
# Out:
#   variable  value
# 0  Dia-FLD  88.08
# 1  Dia-FLD  85.05
# 2  Dia-FLD  83.84
# 3  Dia-FLD  78.99
# 4  Dia-FLD  85.05

# %%
mod=ols('value~variable',data=df_fr7).fit()
aov_table=sm.stats.anova_lm(mod,type=2)
aov_table
# Out:
#              df       sum_sq    mean_sq         F    PR(>F)
# variable    6.0   204.516211  34.086035  4.367533  0.000465
# Residual  133.0  1037.987131   7.804415       NaN       NaN
